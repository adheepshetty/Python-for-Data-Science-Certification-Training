# %% [markdown]
# # Asssignment 1

# %% [raw]
# Evaluate the dataset of the Summer Olympics, London 2012 to:

# %% [raw]
# •	Find and print the name of the country that won maximum gold medals

# %%
import pandas as pd
pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']})
country = pd.DataFrame({'CountryName':['India', 'China' , 'India' , 'China', 'Germany', 'India' , 'India'],'Medals':['Gold', 'Silver', 'Gold', 'Gold', 'Gold', 'Gold', 'Gold']})
country
# Out:
#   CountryName  Medals
# 0       India    Gold
# 1       China  Silver
# 2       India    Gold
# 3       China    Gold
# 4     Germany    Gold
# 5       India    Gold

# %%
country.loc[country.Medals=='Gold', :]
# Out:
#   CountryName Medals
# 0       India   Gold
# 2       India   Gold
# 3       China   Gold
# 4     Germany   Gold
# 5       India   Gold

# %% [raw]
# •	Find and print the countries who won more than 20 gold medals,

# %%
country.loc[: , 'CountryName'].apply([x if x in 'Medals'='Gold'])
# Out:
#              Medals
# CountryName
# China             2
# Germany           1
# India             3

# %% [markdown]
# # Assignment 2

# %% [raw]
# You have been provided with a dataset that lists Ohio State’s leading causes of death from the year 2012.

# %% [raw]
# Using the two data points:
# •	Cause of deaths and
# •	Percentile
# Draw a pie chart to visualize the dataset.

# %%
import pandas as pd
ohio = pd.DataFrame({'Causesofdeaths':[0, 1, 3, 4, 5, 6, 7], 'Percentile':[62, 1,5, 4, 2, 1, 26, 2]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-fb8dd65fab94> in <module>()
#       1 import pandas as pd
# ----> 2 ohio = pd.DataFrame({'Causesofdeaths':[0, 1, 3, 4, 5, 6, 7], 'Percentile':[62, 1,5, 4, 2, 1, 26, 2]})
#
# C:\Users\adhee\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# C:\Users\adhee\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
# ...

# %% [markdown]
# # Assignment 3

# %% [raw]
# Analyze the Federal Aviation Authority (FAA) dataset using Pandas to do the following:
#
# 1.	View
#     a.	aircraft make name
#     b.	state name
#     c.	aircraft model name
#     d.	text information
#     e.	flight phase
#     f.	event description type
#     g.	fatal flag

# %%
import pandas as pd

# %%
faa = pd.read_csv("C:/Intellipaat_python_for_datascience/lecture 6/faa_ai_prelim.csv")

# %%
faa.head()
# Out:
#   UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0      No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 1      No  19-FEB-16      18-FEB-16      23:55:00Z     TAVERNIER
# 2      No  19-FEB-16      18-FEB-16      22:14:00Z       TRENTON
# 3      No  19-FEB-16      18-FEB-16      17:10:00Z     ASHEVILLE
# 4      No  19-FEB-16      18-FEB-16      00:26:00Z     TALKEETNA
#
#    LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0  North Carolina            NaN
# 1         Florida            NaN
# 2      New Jersey            NaN
# 3  North Carolina            NaN
# 4          Alaska            NaN
#
#                                             RMK_TEXT EVENT_TYPE_DESC  \
# 0  AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...        Accident
# 1  AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...        Incident
# 2  AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...        Incident
# 3  AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...        Incident
# ...

# %%
faa.describe()
# Out:
#        ACFT_MISSING_FLAG  FAR_PART  FLT_CRW_INJ_NONE  FLT_CRW_INJ_MINOR  \
# count                0.0       1.0         64.000000           6.000000
# mean                 NaN      91.0          1.218750           1.333333
# std                  NaN       NaN          0.700765           0.516398
# min                  NaN      91.0          1.000000           1.000000
# 25%                  NaN      91.0          1.000000           1.000000
# 50%                  NaN      91.0          1.000000           1.000000
# 75%                  NaN      91.0          1.000000           1.750000
# max                  NaN      91.0          6.000000           2.000000
#
#        FLT_CRW_INJ_SERIOUS  FLT_CRW_INJ_FATAL  FLT_CRW_INJ_UNK  \
# count                  1.0           8.000000              0.0
# mean                   3.0           1.500000              NaN
# std                    NaN           0.534522              NaN
# min                    3.0           1.000000              NaN
# ...

# %%
faa.columns
# Out:
# Index(['UPDATED', 'ENTRY_DATE', 'EVENT_LCL_DATE', 'EVENT_LCL_TIME',
#        'LOC_CITY_NAME', 'LOC_STATE_NAME', 'LOC_CNTRY_NAME', 'RMK_TEXT',
#        'EVENT_TYPE_DESC', 'FSDO_DESC', 'REGIST_NBR', 'FLT_NBR', 'ACFT_OPRTR',
#        'ACFT_MAKE_NAME', 'ACFT_MODEL_NAME', 'ACFT_MISSING_FLAG',
#        'ACFT_DMG_DESC', 'FLT_ACTIVITY', 'FLT_PHASE', 'FAR_PART', 'MAX_INJ_LVL',
#        'FATAL_FLAG', 'FLT_CRW_INJ_NONE', 'FLT_CRW_INJ_MINOR',
#        'FLT_CRW_INJ_SERIOUS', 'FLT_CRW_INJ_FATAL', 'FLT_CRW_INJ_UNK',
#        'CBN_CRW_INJ_NONE', 'CBN_CRW_INJ_MINOR', 'CBN_CRW_INJ_SERIOUS',
#        'CBN_CRW_INJ_FATAL', 'CBN_CRW_INJ_UNK', 'PAX_INJ_NONE', 'PAX_INJ_MINOR',
#        'PAX_INJ_SERIOUS', 'PAX_INJ_FATAL', 'PAX_INJ_UNK', 'GRND_INJ_NONE',
#        'GRND_INJ_MINOR', 'GRND_INJ_SERIOUS', 'GRND_INJ_FATAL', 'GRND_INJ_UNK'],
#       dtype='object')

# %%
faa['ACFT_MAKE_NAME']
# Out:
# 0                   BEECH
# 1                    VANS
# 2                  CESSNA
# 3                 LANCAIR
# 4                  CESSNA
# 5                    BELL
# 6                   PIPER
# 7                  CESSNA
# 8                  BOEING
# 9                     NaN
# 10                 CESSNA
# 11                    NaN
# 12                 CESSNA
# 13                 CESSNA
# 14                  BEECH
# 15                 CESSNA
# 16               CHRISTEN
# 17                  PIPER
# 18                  PIPER
# 19                 CESSNA
# 20                 HUGHES
# 21                 CESSNA
# 22                    NaN
# 23                 BOEING
# 24                  GLOBE
# 25                  PIPER
# 26            GREAT LAKES
# 27                 CESSNA
# 28    CONSOLIDATED VULTEE
# 29                 CESSNA
#              ...
# 53                  PIPER
# 54                 CESSNA
# 55          FLIGHT DESIGN
# 56                  PIPER
# 57                    NaN
# ...

# %%
faa.LOC_STATE_NAME
# Out:
# 0     North Carolina
# 1            Florida
# 2         New Jersey
# 3     North Carolina
# 4             Alaska
# 5             Hawaii
# 6            Florida
# 7            Florida
# 8            Florida
# 9            Florida
# 10          Virginia
# 11           Arizona
# 12          New York
# 13         Louisiana
# 14        California
# 15           Florida
# 16         Louisiana
# 17          Missouri
# 18           Florida
# 19             Texas
# 20     West Virginia
# 21             Texas
# 22           Arizona
# 23          Michigan
# 24          Colorado
# 25         Tennessee
# 26        California
# 27     New Hampshire
# 28        California
# 29          Colorado
#            ...
# 53           Florida
# 54      South Dakota
# 55        California
# 56           Florida
# 57             Idaho
# 58        California
# 59           Arizona
# 60      Pennsylvania
# 61        California
# 62           Arizona
# 63            Oregon
# 64           Montana
# ...

# %%
faa['ACFT_MODEL_NAME']
# Out:
# 0           36
# 1          RV7
# 2          172
# 3          235
# 4          172
# 5          206
# 6         PA24
# 7          210
# 8          747
# 9          NaN
# 10         172
# 11     FIREFLY
# 12         310
# 13         210
# 14         T34
# 15         152
# 16    EAGLE II
# 17        PA34
# 18        PA28
# 19         150
# 20         369
# 21         210
# 22         NaN
# 23         737
# 24        GC1B
# 25        PA20
# 26        2T1A
# 27         560
# 28        BT15
# 29         210
#         ...
# 53        PA28
# 54         150
# 55        CTLS
# 56        PA34
# 57      KITFOX
# 58         NaN
# 59        PA28
# 60        PA34
# 61          36
# 62          33
# 63         206
# 64         206
# 65         175
# 66        PA31
# 67          IV
# 68          35
# 69        M20K
# 70         500
# 71         310
# 72        M20E
# 73          35
# 74       NA265
# 75        M20K
# 76        PA24
# 77         737
# 78        O58B
# 79         F51
# 80       8KCAB
# ...

# %%
faa['RMK_TEXT']
# Out:
# 0     AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...
# 1     AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...
# 2     AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...
# 3     AIRCRAFT ON LANDING, GEAR COLLAPSED, ASHEVILLE...
# 4     AIRCRAFT ON LANDING, NOSE GEAR COLLAPSED, TALK...
# 5     N80918 BELL 206B ROTORCRAFT CRASHED INTO THE W...
# 6     AIRCRAFT GEAR COLLAPSED ON LANDING, BROOKSVILL...
# 7     AIRCRAFT ON LANDING GEAR COLLAPSED, WINTER HAV...
# 8     N859GT ATLAS AIR FLIGHT GTI33 BOEING 747 AIRCR...
# 9     AIRCRAFT, LSA PARADISE P1,  ON LANDING NOSE GE...
# 10    AIRCRAFT ON LANDING WENT OFF THE RUNWAY INTO A...
# 11    N2194X FIREFLY 9 BALLOON, ON LANDING STRUCK TH...
# 12       AIRCRAFT GEAR COLLAPSED ON LANDING, ELMIRA, NY
# 13    AIRCRAFT ON LANDING NOSE GEAR COLLAPSED, LAKEF...
# 14    AIRCRAFT ON TAKEOFF STRUCK RUNWAY LIGHT AT THE...
# 15    AIRCRAFT FORCE LANDED ON A HIGHWAY, NEAR PEMBR...
# 16    AIRCRAFT ON TAKEOFF WENT OFF THE GRASS STRIP A...
# ...

# %%
faa.loc[:,['ACFT_MAKE_NAME','LOC_STATE_NAME','ACFT_MODEL_NAME','RMK_TEXT','FLT_PHASE','EVENT_TYPE_DESC','FATAL_FLAG']]
# Out:
#          ACFT_MAKE_NAME  LOC_STATE_NAME ACFT_MODEL_NAME  \
# 0                 BEECH  North Carolina              36
# 1                  VANS         Florida             RV7
# 2                CESSNA      New Jersey             172
# 3               LANCAIR  North Carolina             235
# 4                CESSNA          Alaska             172
# 5                  BELL          Hawaii             206
# 6                 PIPER         Florida            PA24
# 7                CESSNA         Florida             210
# 8                BOEING         Florida             747
# 9                   NaN         Florida             NaN
# 10               CESSNA        Virginia             172
# 11                  NaN         Arizona         FIREFLY
# 12               CESSNA        New York             310
# 13               CESSNA       Louisiana             210
# 14                BEECH      California             T34
# 15               CESSNA         Florida             152
# ...

# %% [raw]
# 2. Clean the dataset and replace the fatal flag NaN with “No”

# %%
faa['FATAL_FLAG'].fillna('No' , inplace = True)

# %%
faa[:]
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME     LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z        MARSHVILLE
# 1       No  19-FEB-16      18-FEB-16      23:55:00Z         TAVERNIER
# 2       No  19-FEB-16      18-FEB-16      22:14:00Z           TRENTON
# 3       No  19-FEB-16      18-FEB-16      17:10:00Z         ASHEVILLE
# 4       No  19-FEB-16      18-FEB-16      00:26:00Z         TALKEETNA
# 5       No  19-FEB-16      18-FEB-16      20:23:00Z      PEARL HARBOR
# 6       No  18-FEB-16      17-FEB-16      21:15:00Z       BROOKSVILLE
# 7       No  18-FEB-16      17-FEB-16      18:10:00Z      WINTER HAVEN
# 8       No  18-FEB-16      17-FEB-16      13:50:00Z             MIAMI
# 9       No  18-FEB-16      17-FEB-16      15:30:00Z  FERNANDINA BEACH
# 10      No  18-FEB-16      17-FEB-16      15:40:00Z      NEWPORT NEWS
# 11      No  17-FEB-16      15-FEB-16      16:12:00Z           PHOENIX
# ...

# %%
faa['ACFT_MODEL_NAME']
# Out:
# 0           36
# 1          RV7
# 2          172
# 3          235
# 4          172
# 5          206
# 6         PA24
# 7          210
# 8          747
# 9          NaN
# 10         172
# 11     FIREFLY
# 12         310
# 13         210
# 14         T34
# 15         152
# 16    EAGLE II
# 17        PA34
# 18        PA28
# 19         150
# 20         369
# 21         210
# 22         NaN
# 23         737
# 24        GC1B
# 25        PA20
# 26        2T1A
# 27         560
# 28        BT15
# 29         210
#         ...
# 53        PA28
# 54         150
# 55        CTLS
# 56        PA34
# 57      KITFOX
# 58         NaN
# 59        PA28
# 60        PA34
# 61          36
# 62          33
# 63         206
# 64         206
# 65         175
# 66        PA31
# 67          IV
# 68          35
# 69        M20K
# 70         500
# 71         310
# 72        M20E
# 73          35
# 74       NA265
# 75        M20K
# 76        PA24
# 77         737
# 78        O58B
# 79         F51
# 80       8KCAB
# ...

# %% [raw]
# 3. Find the aircraft types and their occurrences in the dataset

# %%
faa.groupby('ACFT_MODEL_NAME').count()
# Out:
#                  UPDATED  ENTRY_DATE  EVENT_LCL_DATE  EVENT_LCL_TIME  \
# ACFT_MODEL_NAME
# 140                    1           1               1               1
# 150                    3           3               3               3
# 152                    2           2               2               2
# 172                    4           4               4               4
# 175                    1           1               1               1
# 180                    1           1               1               1
# 182                    2           2               2               2
# 206                    3           3               3               3
# 210                    4           4               4               4
# 235                    1           1               1               1
# 2T1A                   1           1               1               1
# 310                    2           2               2               2
# ...

# %% [raw]
# 4. Remove all the observations where aircraft names are not available

# %%
faa['ACFT_MODEL_NAME'].dropna(how = 'any')
# Out:
# 0           36
# 1          RV7
# 2          172
# 3          235
# 4          172
# 5          206
# 6         PA24
# 7          210
# 8          747
# 10         172
# 11     FIREFLY
# 12         310
# 13         210
# 14         T34
# 15         152
# 16    EAGLE II
# 17        PA34
# 18        PA28
# 19         150
# 20         369
# 21         210
# 23         737
# 24        GC1B
# 25        PA20
# 26        2T1A
# 27         560
# 28        BT15
# 29         210
# 30          36
# 31         172
#         ...
# 52         182
# 53        PA28
# 54         150
# 55        CTLS
# 56        PA34
# 57      KITFOX
# 59        PA28
# 60        PA34
# 61          36
# 62          33
# 63         206
# 64         206
# 65         175
# 66        PA31
# 67          IV
# 68          35
# 69        M20K
# 70         500
# 71         310
# 72        M20E
# 73          35
# 74       NA265
# 75        M20K
# 76        PA24
# 77         737
# 78        O58B
# 79         F51
# 80       8KCAB
# ...

# %% [raw]
# 5. Display the observations where fatal flag is “Yes”

# %%
faa.FATAL_FLAG == 'Yes'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 53     True
# 54    False
# 55     True
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79     True
# 80     True
# 81     True
# 82     True
# Name: FATAL_FLAG, Length: 83, dtype: bool

# %%
faa[faa.FATAL_FLAG == 'Yes']
# Out:
#    UPDATED ENTRY_DATE EVENT_LCL_DATE EVENT_LCL_TIME LOC_CITY_NAME  \
# 0       No  19-FEB-16      19-FEB-16      00:45:00Z    MARSHVILLE
# 22      No  17-FEB-16      16-FEB-16      20:52:00Z       BUCKEYE
# 53      No  12-FEB-16      11-FEB-16      11:32:00Z        DESTIN
# 55      No  11-FEB-16      11-FEB-16      00:17:00Z        TULARE
# 79      No  08-FEB-16      05-FEB-16      11:17:00Z      MARICOPA
# 80      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 81      No  08-FEB-16      05-FEB-16      23:02:00Z     SAN PEDRO
# 82     Yes  02-FEB-16      02-FEB-16      01:52:00Z        MOBILE
#
#     LOC_STATE_NAME LOC_CNTRY_NAME  \
# 0   North Carolina            NaN
# 22         Arizona            NaN
# 53         Florida  United States
# 55      California            NaN
# 79         Arizona            NaN
# 80      California            NaN
# 81      California            NaN
# 82         Alabama            NaN
#
# ...

# %% [markdown]
# # Assignment 4

# %% [raw]
# A dataset in CSV format is given for the Fire Department of New York City. Analyze the dataset to determine:
# 1.	The total number of fire department facilities in New York city

# %%
fdny = pd.read_csv('C:/Intellipaat_python_for_datascience/lecture 6/FDNY.csv')

# %%
fdny.head(3)
# Out:
#           FacilityName     FacilityAddress    Borough
# 0         FacilityName     FacilityAddress    Borough
# 1   Engine 4/Ladder 15     42 South Street  Manhattan
# 2  Engine 10/Ladder 10  124 Liberty Street  Manhattan

# %%
fdny.drop(0 , axis = 0)
# Out:
#               FacilltyName                                       FacilityName  \
# FacilityName
# 1                        1                                 Engine 4/Ladder 15
# 2                        2                                Engine 10/Ladder 10
# 3                        3                                           Engine 6
# 4                        4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                        5                                           Ladder 8
# 6                        6                                  Engine 9/Ladder 6
# 7                        7                    Engine 15/Ladder 18/Battalion 4
# 8                        8                                Engine 28/Ladder 11
# 9                        9                                           Engine 5
# 10                      10                                          Engine 55
# 11                      11                               Ladder 20/Division 1
# ...

# %%
fdny['Borough'].str.contains('Manhattan').sum()
# Out:
# 48

# %% [raw]
# 2.	The number of fire department facilities in each borough

# %%
fdny.groupby('Borough').count().FacilityName
# Out:
# Borough
# Borough           1
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# Name: FacilityName, dtype: int64

# %% [raw]
# 3.	The facility names in Manhattan

# %%
fdny[fdny['Borough'].str.contains('Manhattan')]
# Out:
#               FacilltyName                                       FacilityName  \
# FacilityName
# 1                        1                                 Engine 4/Ladder 15
# 2                        2                                Engine 10/Ladder 10
# 3                        3                                           Engine 6
# 4                        4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                        5                                           Ladder 8
# 6                        6                                  Engine 9/Ladder 6
# 7                        7                    Engine 15/Ladder 18/Battalion 4
# 8                        8                                Engine 28/Ladder 11
# 9                        9                                           Engine 5
# 10                      10                                          Engine 55
# 11                      11                               Ladder 20/Division 1
# ...
